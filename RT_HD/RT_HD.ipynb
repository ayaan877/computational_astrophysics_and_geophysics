# %%
# Density plots for Rayleigh-Taylor Instability in HD
import numpy as np
import matplotlib.pyplot as plt

files = ['0000', '0003', '0006', '0009', '0012', '0015']
nx, ny = 256, 512

data_list = []
for f in files:
    data = np.fromfile(f"rho.{f}.dbl", dtype=np.float64).reshape((nx, ny), order='F')
    data_list.append(data)

vmin = min(d.min() for d in data_list)
vmax = max(d.max() for d in data_list)

fig, axes = plt.subplots(2, 3, figsize=(8, 8))
fig.suptitle("RT Instability (HD) - Density Distribution Evolution", fontsize=14)

for ax, f, Z in zip(axes.flat, files, data_list):
    im = ax.imshow(Z.T, origin='lower', aspect=1, cmap='viridis', vmin=vmin, vmax=vmax, extent=[-0.5, 0.5, -1, 1])
    ax.label_outer()
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_title(f"T = {int(f)}s")

cbar = fig.colorbar(im, ax=axes.ravel().tolist(), label='Density')

plt.savefig("../RT_HD_rho.png", dpi=300)
plt.show()

# %%
# Velocity magnitude plots for Rayleigh-Taylor Instability in HD
import numpy as np
import matplotlib.pyplot as plt

files = ['0000', '0003', '0006', '0009', '0012', '0015']
nx, ny = 256, 512

v_list = []
for f in files:
    vx1 = np.fromfile(f"vx1.{f}.dbl", dtype=np.float64).reshape((nx, ny), order='F')
    vx2 = np.fromfile(f"vx2.{f}.dbl", dtype=np.float64).reshape((nx, ny), order='F')
    vx3 = np.fromfile(f"vx3.{f}.dbl", dtype=np.float64).reshape((nx, ny), order='F')

    v_mag = np.sqrt(vx1**2 + vx2**2 + vx3**2)
    v_list.append(v_mag)

vmin = min(v.min() for v in v_list)
vmax = max(v.max() for v in v_list)

fig, axes = plt.subplots(2, 3, figsize=(8, 8), sharex=True, sharey=True)
fig.suptitle("RT Instability (HD) - Velocity Distribution Evolution", fontsize=14)

for ax, f, V in zip(axes.flat, files, v_list):
    im = ax.imshow(V.T, origin='lower', aspect=1, cmap='plasma', vmin=vmin, vmax=vmax, extent=[-0.5, 0.5, -1, 1])
    ax.label_outer()
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_title(f"T = {int(f)}s")

cbar = fig.colorbar(im, ax=axes.ravel().tolist(), label='Velocity Magnitude')

plt.savefig("../RT_HD_v.png", dpi=300)
plt.show()

# %%
# Density plots for Rayleigh-Taylor Instability in MHD
import numpy as np
import matplotlib.pyplot as plt
import os

files = ['0000', '0003', '0006', '0009', '0012', '0015']

for f in files:
    nx, ny = 256, 512

    data = np.fromfile(f"rho.{f}.dbl", dtype=np.float64)
    Z = data.reshape((nx, ny), order='F')

    plt.imshow(Z.T, origin='lower', aspect='auto', cmap='viridis')
    plt.colorbar(label='Density')
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title("Density Distribution")
    # plt.savefig(os.path.join("..", f"RT_HD_rho{f}.png"), dpi=300)
    plt.show()

# %%
# Velocity plots for Rayleigh-Taylor Instability in MHD
import numpy as np
import matplotlib.pyplot as plt
import os

files = ['0000', '0003', '0006', '0009', '0012', '0015']

for f in files:
    nx, ny = 256, 512

    vx1 = np.fromfile(f"vx1.{f}.dbl", dtype=np.float64).reshape((nx, ny), order='F')
    vx2 = np.fromfile(f"vx2.{f}.dbl", dtype=np.float64).reshape((nx, ny), order='F')
    vx3 = np.fromfile(f"vx3.{f}.dbl", dtype=np.float64).reshape((nx, ny), order='F')

    v_mag = np.sqrt(vx1**2 + vx2**2 + vx3**2)

    plt.imshow(v_mag.T, origin='lower', aspect='auto', cmap='plasma')
    plt.colorbar(label='Velocity Magnitude')
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title("Velocity Distribution")
    # plt.savefig(os.path.join("..", f"RT_HD_v{f}.png"), dpi=300)
    plt.show()
