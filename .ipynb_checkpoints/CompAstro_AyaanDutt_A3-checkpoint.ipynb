# %% [markdown]
# # Rayleigh-Taylor Simulation with PLUTO
#
# <p align = "center">
#   <img src="RT_HD_rho0000.png" width="300" />
#   <img src="RT_HD_rho0003.png" width="300" />
#   <img src="RT_HD_rho0006.png" width="300" />
#   <img src="RT_MHD_rho0009.png" width="300" />
#   <img src="RT_MHD_rho0012.png" width="300" />
#   <img src="RT_HD_rho0015.png" width="300" />
# </p>
